# %% [markdown]
# ## Zadanie B

# %%
using Roots
using Plots
using ForwardDiff
using DataFrames

# %%
f(z) = (z+1)^2 * (z-1)^2
roots = find_zeros(f, -10, 10)
# Out:
# 2-element Array{Float64,1}:
#  -1.0000000000000002
#   1.0000000000000002

# %%
plot(f, (-2, 2)...)
